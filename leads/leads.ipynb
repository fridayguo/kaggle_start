# %%
import pandas as pd
import numpy as np
import os

# 改变工作目录 
os.getcwd()
os.chdir(os.getcwd()+'./leads/')
os.getcwd()
# Out:
# WindowsErrorTraceback (most recent call last)
# <ipython-input-12-df860fb5d04b> in <module>()
#       5 # 改变工作目录
#       6 os.getcwd()
# ----> 7 os.chdir(os.getcwd()+'./leads/')
#       8 os.getcwd()
#
# WindowsError: [Error 2] : 'D:\\PycharmProjects\\kaggle_start\\leads./leads/'

# %%
df = pd.read_csv('./leads_info_20170910', sep='\t')
df.describe()
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>f_sys_assign_day</th>
#       <th>f_internal_follow_up_res</th>
#       <th>label</th>
#       <th>f_leads_id</th>
#       <th>f_leads_from</th>
#       <th>FQQ</th>
#       <th>company_name</th>
#       <th>FSize</th>
#       <th>FCityName</th>
#       <th>city_level</th>
#       <th>...</th>
#       <th>leads_id</th>
#       <th>visit_day_num_7</th>
#       <th>lvl_visit_day_num</th>
#       <th>url_num_7</th>
#       <th>lvl_url_num</th>
#       <th>wpa_click_num_7</th>
#       <th>lvl_wpa_click</th>
#       <th>viewtime_7</th>
#       <th>lvl_viewtime</th>
#       <th>utm_term</th>
#     </tr>
#   </thead>
#   <tbody>
# ...

# %%
df.head()
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>f_sys_assign_day</th>
#       <th>f_internal_follow_up_res</th>
#       <th>f_internal_follow_up_res_name</th>
#       <th>label</th>
#       <th>f_leads_id</th>
#       <th>f_leads_from</th>
#       <th>laiyuan</th>
#       <th>FTel</th>
#       <th>FQQ</th>
#       <th>FUserName</th>
#       <th>...</th>
#       <th>url_num_7</th>
#       <th>lvl_url_num</th>
#       <th>wpa_click_num_7</th>
#       <th>lvl_wpa_click</th>
#       <th>viewtime_7</th>
#       <th>lvl_viewtime</th>
#       <th>utm_term</th>
#       <th>utm_source</th>
#       <th>utm_medium</th>
#       <th>utm_campaign</th>
#     </tr>
#   </thead>
#   <tbody>
# ...

# %%
df.dtypes
# Out:
# f_sys_assign_day                   int64
# f_internal_follow_up_res           int64
# f_internal_follow_up_res_name     object
# label                              int64
# f_leads_id                         int64
# f_leads_from                       int64
# laiyuan                           object
# FTel                              object
# FQQ                              float64
# FUserName                         object
# company_name                     float64
# FSize                            float64
# FCityName                        float64
# city_level                         int64
# age                               object
# lvl_age                            int64
# is_has_age                         int64
# edu                               object
# lvl_edu                            int64
# is_has_edu                         int64
# income                            object
# lvl_income                         int64
# is_has_income                      int64
# ...

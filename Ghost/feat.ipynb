# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt

# %%
train = pd.read_csv('./Ghost/train.csv')
test = pd.read_csv('./Ghost/test.csv')

print 'train.shape:', train.shape
print 'test.shape:', test.shape
# Out:
# train.shape: (371, 7)
# test.shape: (529, 6)

# %%
train.head()
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>bone_length</th>
#       <th>rotting_flesh</th>
#       <th>hair_length</th>
#       <th>has_soul</th>
#       <th>color</th>
#       <th>type</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>0.354512</td>
#       <td>0.350839</td>
#       <td>0.465761</td>
#       <td>0.781142</td>
#       <td>clear</td>
#       <td>Ghoul</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>0.575560</td>
#       <td>0.425868</td>
#       <td>0.531401</td>
#       <td>0.439899</td>
#       <td>green</td>
#       <td>Goblin</td>
#     </tr>
# ...

# %%
train.describe()
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>bone_length</th>
#       <th>rotting_flesh</th>
#       <th>hair_length</th>
#       <th>has_soul</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>371.000000</td>
#       <td>371.000000</td>
#       <td>371.000000</td>
#       <td>371.000000</td>
#       <td>371.000000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>443.676550</td>
#       <td>0.434160</td>
#       <td>0.506848</td>
#       <td>0.529114</td>
#       <td>0.471392</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>263.222489</td>
#       <td>0.132833</td>
#       <td>0.146358</td>
# ...

# %%
train.describe(include=['object'])
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>color</th>
#       <th>type</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>371</td>
#       <td>371</td>
#     </tr>
#     <tr>
#       <th>unique</th>
#       <td>6</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>top</th>
#       <td>white</td>
#       <td>Ghoul</td>
#     </tr>
#     <tr>
#       <th>freq</th>
#       <td>137</td>
#       <td>129</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
nrow = train.shape[0]
min_cate = max(10, nrow*0.01)
unique_num = train.nunique(axis=0)
cate_col_num = unique_num[unique_num<=min_cate]
cate_col_name = cate_col_num.index.tolist()
print nrow, min_cate, cate_col_name

for col in cate_col_name:
    train[col] = train[col].astype('category')
    
cate_index = [ id for id,val in enumerate(train.columns.tolist()) if val in cate_col_name ]
# Out:
# 371 10 ['color', 'type']

# %%
[ train.columns.isin(cate_col_name) ]

[ id for id,val in enumerate(train.columns.tolist()) if val in cate_col_name ]
# Out:
# [5, 6]

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 371 entries, 0 to 370
# Data columns (total 7 columns):
# id               371 non-null int64
# bone_length      371 non-null float64
# rotting_flesh    371 non-null float64
# hair_length      371 non-null float64
# has_soul         371 non-null float64
# color            371 non-null category
# type             371 non-null category
# dtypes: category(2), float64(4), int64(1)
# memory usage: 15.6 KB

# %%
from sklearn import preprocessing
enc = preprocessing.OneHotEncoder(categorical_features=cate_index)
# enc.fit(train[cate_col_name])
#train[cate_col_name].astype('category')
train['type'] = train['type'].astype('category')
#enc.fit(train[cate_col_name])
train.dtypes
train['type'].cat.categories
# Out:
# Index([u'Ghost', u'Ghoul', u'Goblin'], dtype='object')

# %%
cate_col_name = ['color']
dm = pd.get_dummies(train, columns=cate_col_name, drop_first=True)
dm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 371 entries, 0 to 370
# Data columns (total 11 columns):
# id               371 non-null int64
# bone_length      371 non-null float64
# rotting_flesh    371 non-null float64
# hair_length      371 non-null float64
# has_soul         371 non-null float64
# type             371 non-null category
# color_blood      371 non-null uint8
# color_blue       371 non-null uint8
# color_clear      371 non-null uint8
# color_green      371 non-null uint8
# color_white      371 non-null uint8
# dtypes: category(1), float64(4), int64(1), uint8(5)
# memory usage: 16.8 KB
